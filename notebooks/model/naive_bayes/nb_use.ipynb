# %%
import joblib
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize 

nltk.download('stopwords')
nltk.download('punkt')

def text_preprocessing(text):
    stop_words = set(stopwords.words('english')) 
    stemmer = PorterStemmer(PorterStemmer.ORIGINAL_ALGORITHM)
  
    tokens = word_tokenize(text)
    splitted_words_without_stops = [word for word in tokens if not word in stop_words]
    splitted_words_without_puncs = [word for word in splitted_words_without_stops if word.isalnum()] 
    stemmed_words = [stemmer.stem(word) for word in splitted_words_without_puncs]

    return ' '.join(stemmed_words)

# carregar o modelo de Naive Bayes treinado
pipe_NB_loaded = joblib.load('naive_bayes_model.pkl')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Igor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Igor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import pandas as pd

df = pd.read_csv('C:\\data_to_analyze.csv')
df['TOTAL_REVIEW'] = df['TOTAL_REVIEW'].fillna('')

sentiments = []
for review in df['TOTAL_REVIEW']:
    sentiment = pipe_NB_loaded.predict([text_preprocessing(str(review))])[0]
    if sentiment == 1:
        sentiments.append('Positive')
    elif sentiment == 0:
        sentiments.append('Neutral')
    else:
        sentiments.append('Negative')

df['sentiment'] = sentiments

df.head()
# Out:
#           HOTEL_NAME                             HOTEL_ADDRESS  AVEREGE_SCORE  \
# 0  A La Villa Madame  44 Rue Madame 6th arr 75006 Paris France            8.8
# 1  A La Villa Madame  44 Rue Madame 6th arr 75006 Paris France            8.8
# 2  A La Villa Madame  44 Rue Madame 6th arr 75006 Paris France            8.8
# 3  A La Villa Madame  44 Rue Madame 6th arr 75006 Paris France            8.8
# 4  A La Villa Madame  44 Rue Madame 6th arr 75006 Paris France            8.8
#
#          LAT       LNG REVIEW_DATE  REVIEWER_SCORE  \
# 0  48.848861  2.331526   5/29/2017            10.0
# 1  48.848861  2.331526   8/15/2015            10.0
# 2  48.848861  2.331526   8/26/2015             9.6
# 3  48.848861  2.331526   9/30/2015             9.6
# 4  48.848861  2.331526  10/13/2015             7.9
#
#                                         TOTAL_REVIEW  \
# 0   The bed was extra comfy the street is really ...
# 1   no dogs allowed policy Adorable little hotel ...
# 2   Everything was above expectation Will definit...
# 3   Next to an elementary school noisy from 8 30 ...
# 4   Location et breakfast There is a Italian rest...
#
#                                      POSITIVE_REVIEW  \
# 0   The bed was extra comfy the street is really ...
# 1   Adorable little hotel beautifully decorated c...
# 2   Everything was above expectation Will definit...
# 3   Pleasant service great breakfast walking dist...
# 4   Location et breakfast There is a Italian rest...
#
#                                      NEGATIVE_REVIEW  \
# 0                                                NaN
# 1                             no dogs allowed policy
# 2                                                NaN
# 3   Next to an elementary school noisy from 8 30 ...
# 4                                                NaN
#
#                                                 TAGS sentiment
# 0  [' Leisure trip ', ' Solo traveler ', ' Classi...  Positive
# 1  [' Leisure trip ', ' Solo traveler ', ' Deluxe...  Positive
# 2  [' Leisure trip ', ' Couple ', ' Executive Dou...  Positive
# 3  [' Leisure trip ', ' Couple ', ' Deluxe Double...  Positive
# 4  [' Leisure trip ', ' Couple ', ' Classic Room ...  Positive

# %%
df.to_csv('data_analyzed_nb.csv', index=False)
